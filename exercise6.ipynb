# %% [markdown]
# # Training and predicting

# %% [markdown]
# **IF YOU SEE MESSY TABLE OUTPUTS PLEASE RUN THE CELL BELOW**
#
# (some CPDs are really long so we need to tweak the config to disable wrapping text and add a horizontal scrollbar to the output area)

# %%
# %%html
# <style>
# div.output_area pre {
#     white-space: pre;
# }
# </style>
# Out:
# <style>
# div.output_area pre {
#     white-space: pre;
# }
# </style>

# %%
import pandas as pd
import numpy as np
import random
from pgmpy.models import BayesianModel
from pgmpy.estimators import BayesianEstimator
from ourFunctions import *

# %%
# read csv file
df = pd.read_csv('data_discretized.csv')
dfBackUp = pd.read_csv('data_discretized.csv')

# %%
df
# Out:
#        HomeTeamName  AwayTeamName Result HomeAverageGoals AwayAverageGoals  \
# 0            France    Yugoslavia   Lost     NoGamePlayed     NoGamePlayed
# 1    Czechoslovakia  Soviet Union   Lost     NoGamePlayed     NoGamePlayed
# 2    Czechoslovakia        France    Won              Low             High
# 3      Soviet Union    Yugoslavia    Won             High             High
# 4             Spain       Hungary    Won     NoGamePlayed     NoGamePlayed
# ..              ...           ...    ...              ...              ...
# 281         Germany         Italy   Draw             High              Mid
# 282          France       Iceland    Won             High             High
# 283        Portugal         Wales    Won              Mid             High
# 284         Germany        France   Lost              Mid             High
# 285        Portugal        France    Won              Mid             High
#
#     Home5LastGames Away5LastGames                 Stage              City  \
# 0          Neutral        Neutral           Semi-finals             Paris
# 1          Neutral        Neutral           Semi-finals         Marseille
# 2              Bad            Bad  Third place play-off         Marseille
# 3             Good           Good                 Final             Paris
# 4          Neutral        Neutral           Semi-finals            Madrid
# ..             ...            ...                   ...               ...
# 281           Good           Good        Quarter-finals          Bordeaux
# 282           Good           Good        Quarter-finals       Saint-Denis
# 283           Good           Good           Semi-finals  Décines-Charpieu
# 284           Good           Good           Semi-finals         Marseille
# 285           Good           Good                 Final       Saint-Denis
#
#      Year
# 0    1960
# 1    1960
# 2    1960
# 3    1960
# 4    1964
# ..    ...
# 281  2016
# 282  2016
# 283  2016
# 284  2016
# 285  2016
#
# [286 rows x 10 columns]

# %% [markdown]
# ## (a) and (b) Build a model using pgmpy, predict results of some games and calculate the conditional probability of winning the Euro championship of each country

# %% [markdown]
# We create a training data set by selected only necessary columns.

# %%
data = df[['HomeAverageGoals', 'AwayAverageGoals', 'Home5LastGames', 'Away5LastGames', 'City', 'Result']]
data
# Out:
#     HomeAverageGoals AwayAverageGoals Home5LastGames Away5LastGames  \
# 0       NoGamePlayed     NoGamePlayed        Neutral        Neutral
# 1       NoGamePlayed     NoGamePlayed        Neutral        Neutral
# 2                Low             High            Bad            Bad
# 3               High             High           Good           Good
# 4       NoGamePlayed     NoGamePlayed        Neutral        Neutral
# ..               ...              ...            ...            ...
# 281             High              Mid           Good           Good
# 282             High             High           Good           Good
# 283              Mid             High           Good           Good
# 284              Mid             High           Good           Good
# 285              Mid             High           Good           Good
#
#                  City Result
# 0               Paris   Lost
# 1           Marseille   Lost
# 2           Marseille    Won
# 3               Paris    Won
# 4              Madrid    Won
# ..                ...    ...
# 281          Bordeaux   Draw
# 282       Saint-Denis    Won
# 283  Décines-Charpieu    Won
# 284         Marseille   Lost
# 285       Saint-Denis    Won
#
# [286 rows x 6 columns]

# %% [markdown]
# Creating the Bayesian model.

# %%
r = 'Result'
ha = 'HomeAverageGoals'
aa = 'AwayAverageGoals'
hl = 'Home5LastGames'
al = 'Away5LastGames'
c = 'City'

model = BayesianModel([(ha, hl), (aa, al),
                       (hl, r), (al, r), 
                       (c, ha), (c, aa),
                       (ha, r), (aa, r)])

# %% [markdown]
# Let the model learn from data.

# %%
model.fit(data, estimator=BayesianEstimator, prior_type="BDeu")

# %% [markdown]
# CPDs at nodes after training.
#
# (some tables are really long so please use the scrollbar)

# %%
print(model.get_cpds(r))
# Out:
# +------------------+------------------------+------------------------+------------------------+--------------------------------+------------------------+------------------------+------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+------------------------+------------------------+------------------------+--------------------------------+------------------------+------------------------+------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+------------ ...
# | Away5LastGames   | Away5LastGames(Bad)    | Away5LastGames(Bad)    | Away5LastGames(Bad)    | Away5LastGames(Bad)            | Away5LastGames(Bad)    | Away5LastGames(Bad)    | Away5LastGames(Bad)    | Away5LastGames(Bad)            | Away5LastGames(Bad)     | Away5LastGames(Bad)     | Away5LastGames(Bad)     | Away5LastGames(Bad)            | Away5LastGames(Bad)    | Away5LastGames(Bad)   | Away5LastGames(Bad)   | Away5LastGames(Bad)            | Away5LastGames(Bad)    | Away5LastGames(Bad)   | Away5LastGames(Bad)   | Away5LastGames(Bad)            | Away5LastGames(Bad)     | Away5LastGames(Bad)     | Away5LastGames(Bad)     | Away5LastGames(Bad)            | Away5LastGames(Bad)    | Away5LastGames(Bad)   | Away5LastGames(Bad)   | Away5LastGames(Bad)            | Away5LastGames(Bad)    | Away5LastGames(Bad)   | Away5LastGames(Bad)   | Away5LastGames(Bad)            | Away5LastGames(Bad)     | Away5LastGames(Bad)     | Away5LastGames(Bad)     | Away5LastGames(Bad)            | Away5LastGames(Bad)            | Away5LastGames(Bad)            | Away5LastGames(Bad)            | Away5LastGames(Bad)            | Away5LastGames(Bad)            | Away5LastGames(Bad)            | Away5LastGames(Bad)            | Away5LastGames(Bad)            | Away5LastGames(Bad)            | Away5LastGames(Bad)            | Away5LastGames(Bad)            | Away5LastGames(Bad)            | Away5LastGames(Good)   | Away5LastGames(Good)   | Away5LastGames(Good)   | Away5LastGames(Good)           | Away5LastGames(Good)   | Away5LastGames(Good)   | Away5LastGames(Good)   | Away5LastGames(Good)           | Away5LastGames(Good)    | Away5LastGames(Good)    | Away5LastGames(Good)    | Away5LastGames(Good)           | Away5LastGames(Good)   | Away5LastGames(Good)  | Away5LastGames(Good)  | Away5LastGames(Good)           | Away5LastGames(Good)   | Away5LastGames(Good)  | Away5LastGames(Good)  | Away5LastGames(Good)           | Away5LastGames(Good)    | Away5LastGames(Good)    | Away5LastGames(Good)    | Away5LastGames(Good)           | Away5LastGames(Good)   | Away5LastGames(Good)  | Away5LastGames(Good)  | Away5LastGames(Good)           | Away5LastGames(Good)   | Away5LastGames(Good)  | Away5LastGames(Good)  | Away5LastGames(Good)           | Away5LastGames(Good)    | Away5LastGames(Good)    | Away5LastGames(Good)    | Away5LastGames(Good)           | Away5LastGames(Good)           | Away5LastGames(Good)           | Away5LastGames(Good)           | Away5LastGames(Good)           | Away5LastGames(Good)           | Away5LastGames(Good)           | Away5LastGames(Good)           | Away5LastGames(Good)           | Away5LastGames(Good)           | Away5LastGames(Good)           | Away5LastGames(Good)           | Away5LastGames(Good)           | Away5LastGames(Neutral) | Away5LastGames(Neutral) | Away5LastGames(Neutral) | Away5LastGames(Neutral)        | Away5LastGames(Neutral) | Away5LastGames(Neutral) | Away5LastGames(Neutral) | Away5LastGames(Neutral)        | Away5LastGames(Neutral) | Away5LastGames(Neutral) | Away5LastGames(Neutral) | Away5LastGames(Neutral)        | Away5LastGames(Neutral) | Away5LastGames(Neutral) | Away5LastGames(Neutral) | Away5LastGames(Neutral)        | Away5LastGames(Neutral) | Away5LastGames(Neutral) | Away5LastGames(Neutral) | Away5LastGames(Neutral)        | Away5LastGames(Neutral) | Away5LastGames(Neutral) | Away5LastGames(Neutral) | Away5LastGames(Neutral)        | Away5LastGames(Neutral) | Away5LastGames(Neutral) | Away5LastGames(Neutral) | Away5LastGames(Neutral)        | Away5LastGames(Neutral) | Away5LastGames(Neutral) | Away5LastGames(Neutral) | Away5LastGames(Neutral)        | Away5LastGames(Neutral) | Away5LastGames(Neutral) | Away5LastGames(Neutral) | Away5LastGames(Neutral)        | Away5LastGames(Neutral)        | Away5LastGames(Neutral)        | Away5LastGames(Neutral)        | Away5LastGames(Neutral)        | Away5LastGames(Neutral)        | Away5LastGames(Neutral)        | Away5LastGames(Neutral)        | Away5LastGa ...
# +------------------+------------------------+------------------------+------------------------+--------------------------------+------------------------+------------------------+------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+------------------------+------------------------+------------------------+--------------------------------+------------------------+------------------------+------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+------
Home5LastGames(Neutral) | Home5LastGames(Neutral) | Home5LastGames(Neutral) | Home5LastGames(Neutral)        | Home5LastGames(Bad)            | Home5LastGames(Bad)            | Home5LastGames(Bad)            | Home5LastGames(Bad)            | Home5LastGames(Good)           | Home5LastGames(Good)           | Home5LastGames(Good)           | Home5LastGames(Good)           | Home5LastGames(Neutral)        | Home5LastGames(Neutral)        | Home5LastGames(Neutral)        | Home5LastGames(Neutral)        | Home5LastGames(Bad)    | Home5LastGames(Bad)    | Home5LastGames(Bad)    | Home5LastGames(Bad)            | Home5LastGames(Good)   | Home5LastGames(Good)   | Home5LastGames(Good)   | Home5LastGames(Good)           | Home5LastGames(Neutral) | Home5LastGames(Neutral) | Home5LastGames(Neutral) | Home5LastGames(Neutral)        | Home5LastGames(Bad)    | Home5LastGames(Bad)   | Home5LastGames(Bad)   | Home5LastGames(Bad)            | Home5LastGames(Good)   | Home5LastGames(Good)  | Home5LastGames(Good)  | Home5LastGames(Good)           | Home5LastGames(Neutral) | Home5LastGames(Neutral) | Home5LastGames(Neutral) | Home5LastGames(Neutral)        | Home5LastGames(Bad)    | Home5LastGames(Bad)   | Home5LastGames(Bad)   | Home5LastGames(Bad)            | Home5LastGames(Good)   | Home5LastGames(Good)  | Home5LastGames(Good)  | Home5LastGames(Good)           | Home5LastGames(Neutral) | Home5LastGames(Neutral) | Home5LastGames(Neutral) | Home5LastGames(Neutral)        | Home5LastGames(Bad)            | Home5LastGames(Bad)            | Home5LastGames(Bad)            | Home5LastGames(Bad)            | Home5LastGames(Good)           | Home5LastGames(Good)           | Home5LastGames(Good)           | Home5LastGames(Good)           | Home5LastGames(Neutral)        | Home5LastGames(Neutral)        | Home5LastGames(Neutral)        | Home5LastGames(Neutral)        | Home5LastGames(Bad)     | Home5LastGames(Bad)     | Home5LastGames(Bad)     | Home5LastGames(Bad)            | Home5LastGames(Good)    | Home5LastGames(Good)    | Home5LastGames(Good)    | Home5LastGames(Good)           | Home5LastGames(Neutral) | Home5LastGames(Neutral) | Home5LastGames(Neutral) | Home5LastGames(Neutral)        | Home5LastGames(Bad)     | Home5LastGames(Bad)     | Home5LastGames(Bad)     | Home5LastGames(Bad)            | Home5LastGames(Good)    | Home5LastGames(Good)    | Home5LastGames(Good)    | Home5LastGames(Good)           | Home5LastGames(Neutral) | Home5LastGames(Neutral) | Home5LastGames(Neutral) | Home5LastGames(Neutral)        | Home5LastGames(Bad)     | Home5LastGames(Bad)     | Home5LastGames(Bad)     | Home5LastGames(Bad)            | Home5LastGames(Good)    | Home5LastGames(Good)    | Home5LastGames(Good)    | Home5LastGames(Good)           | Home5LastGames(Neutral) | Home5LastGames(Neutral) | Home5LastGames(Neutral) | Home5LastGames(Neutral)        | Home5LastGames(Bad)            | Home5LastGames(Bad)            | Home5LastGames(Bad)            | Home5LastGames(Bad)            | Home5LastGames(Good)           | Home5LastGames(Good)           | Home5LastGames(Good)           | Home5LastGa ...
# +------------------+------------------------+------------------------+------------------------+--------------------------------+------------------------+------------------------+------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+------------------------+------------------------+------------------------+--------------------------------+------------------------+------------------------+------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+------------ ...
# | HomeAverageGoals | HomeAverageGoals(High) | HomeAverageGoals(Low)  | HomeAverageGoals(Mid)  | HomeAverageGoals(NoGamePlayed) | HomeAverageGoals(High) | HomeAverageGoals(Low)  | HomeAverageGoals(Mid)  | HomeAverageGoals(NoGamePlayed) | HomeAverageGoals(High)  | HomeAverageGoals(Low)   | HomeAverageGoals(Mid)   | HomeAverageGoals(NoGamePlayed) | HomeAverageGoals(High) | HomeAverageGoals(Low) | HomeAverageGoals(Mid) | HomeAverageGoals(NoGamePlayed) | HomeAverageGoals(High) | HomeAverageGoals(Low) | HomeAverageGoals(Mid) | HomeAverageGoals(NoGamePlayed) | HomeAverageGoals(High)  | HomeAverageGoals(Low)   | HomeAverageGoals(Mid)   | HomeAverageGoals(NoGamePlayed) | HomeAverageGoals(High) | HomeAverageGoals(Low) | HomeAverageGoals(Mid) | HomeAverageGoals(NoGamePlayed) | HomeAverageGoals(High) | HomeAverageGoals(Low) | HomeAverageGoals(Mid) | HomeAverageGoals(NoGamePlayed) | HomeAverageGoals(High)  | HomeAverageGoals(Low)   | HomeAverageGoals(Mid)   | HomeAverageGoals(NoGamePlayed) | HomeAverageGoals(High)         | HomeAverageGoals(Low)          | HomeAverageGoals(Mid)          | HomeAverageGoals(NoGamePlayed) | HomeAverageGoals(High)         | HomeAverageGoals(Low)          | HomeAverageGoals(Mid)          | HomeAverageGoals(NoGamePlayed) | HomeAverageGoals(High)         | HomeAverageGoals(Low)          | HomeAverageGoals(Mid)          | HomeAverageGoals(NoGamePlayed) | HomeAverageGoals(High) | HomeAverageGoals(Low)  | HomeAverageGoals(Mid)  | HomeAverageGoals(NoGamePlayed) | HomeAverageGoals(High) | HomeAverageGoals(Low)  | HomeAverageGoals(Mid)  | HomeAverageGoals(NoGamePlayed) | HomeAverageGoals(High)  | HomeAverageGoals(Low)   | HomeAverageGoals(Mid)   | HomeAverageGoals(NoGamePlayed) | HomeAverageGoals(
 0.3333333333333333             | 0.3333333333333333             | 0.3333333333333333             | 0.3333333333333333             | 0.3333333333333333             | 0.3333333333333333             | 0.3333333333333333             | 0.3333333333333333             | 0.3333333333333333             | 0.3333333333333333             | 0.3333333333333333             | 0.3333333333333333             | 0.3333333333333333             | 0.9776286353467561     | 0.37481993661768936    | 0.497155858930603      | 0.3333333333333333             | 0.4497978047371462     | 0.497155858930603      | 0.3529012094034516     | 0.3333333333333333             | 0.2507171543316122      | 0.003813882532418002    | 0.33333333333333337     | 0.3333333333333333             | 0.3333333333333333     | 0.01118568232662192   | 0.3333333333333333    | 0.3333333333333333             | 0.9776286353467561     | 0.01118568232662192   | 0.3333333333333333    | 0.3333333333333333             | 0.3333333333333333      | 0.3333333333333333      | 0.01118568232662192     | 0.3333333333333333             | 0.3333333333333333     | 0.0028686173264486515 | 0.01118568232662192   | 0.3333333333333333             | 0.33333333333333337    | 0.01118568232662192   | 0.3995402298850575    | 0.3333333333333333             | 0.3333333333333333      | 0.497155858930603       | 0.01118568232662192     | 0.3333333333333333             | 0.3333333333333333             | 0.3333333333333333             | 0.3333333333333333             | 0.3333333333333333             | 0.3333333333333333             | 0.3333333333333333             | 0.3333333333333333             | 0.3333333333333333             | 0.3333333333333333             | 0.3333333333333333             | 0.3333333333333333             | 0.3333333333333333             | 0.3333333333333333      | 0.005688282138794085    | 0.01118568232662192     | 0.3333333333333333             | 0.7464142283419392      | 0.3333333333333333      | 0.003813882532418002    | 0.3333333333333333             | 0.01118568232662192     | 0.3333333333333333      | 0.497155858930603       | 0.3333333333333333             | 0.01118568232662192     | 0.49856569133677564     | 0.9776286353467561      | 0.3333333333333333             | 0.6628527841342486      | 0.3333333333333333      | 0.6628527841342486      | 0.3333333333333333             | 0.3333333333333333      | 0.3333333333333333      | 0.3995402298850575      | 0.3333333333333333             | 0.9776286353467561      | 0.3995402298850575      | 0.005688282138794083    | 0.3333333333333333             | 0.4541640444724145      | 0.3333333333333333      | 0.33333333333333337     | 0.3333333333333333             | 0.9886234357224117      | 0.33333333333333337     | 0.9776286353467561      | 0.3333333333333333             | 0.3333333333333333             | 0.3333333333333333             | 0.3333333333333333             | 0.3333333333333333             | 0.3333333333333333             | 0.3333333333333333             | 0.3333333333333333             | 0.333333333 ...
# +------------------+------------------------+------------------------+------------------------+--------------------------------+------------------------+------------------------+------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+------------------------+------------------------+------------------------+--------------------------------+------------------------+------------------------+------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+------------------------+-----------------------+-----------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+-------------------------+-------------------------+-------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+------------ ...

# %% [markdown]
# There are many cases where the probability of Draw - Lost - Won is 1/3 - 1/3 - 1/3. This is mostly because a *NoGamePlayed* pairs with a *Low/Mid/High*, which, in our data frame doesn't exit (NoGamePlayed always pairs with NoGamePlayed). Therefore, we don't need to worry about it because such cases don't happen in our data anyway. Let's just ignore these 0.3333... for now.

# %%
print(model.get_cpds(hl))
# Out:
# +-------------------------+------------------------+-----------------------+-----------------------+--------------------------------+
# | HomeAverageGoals        | HomeAverageGoals(High) | HomeAverageGoals(Low) | HomeAverageGoals(Mid) | HomeAverageGoals(NoGamePlayed) |
# +-------------------------+------------------------+-----------------------+-----------------------+--------------------------------+
# | Home5LastGames(Bad)     | 0.05644302449414271    | 0.7134238310708899    | 0.15867944621938232   | 0.005257623554153523           |
# +-------------------------+------------------------+-----------------------+-----------------------+--------------------------------+
# | Home5LastGames(Good)    | 0.8104366347177848     | 0.07993966817496231   | 0.4781682641107561    | 0.005257623554153523           |
# +-------------------------+------------------------+-----------------------+-----------------------+--------------------------------+
# | Home5LastGames(Neutral) | 0.13312034078807242    | 0.20663650075414783   | 0.36315228966986157   | 0.989484752891693              |
# +-------------------------+------------------------+-----------------------+-----------------------+--------------------------------+

# %%
print(model.get_cpds(al))
# Out:
# +-------------------------+------------------------+-----------------------+-----------------------+--------------------------------+
# | AwayAverageGoals        | AwayAverageGoals(High) | AwayAverageGoals(Low) | AwayAverageGoals(Mid) | AwayAverageGoals(NoGamePlayed) |
# +-------------------------+------------------------+-----------------------+-----------------------+--------------------------------+
# | Away5LastGames(Bad)     | 0.04104104104104103    | 0.6048265460030166    | 0.1285551763367463    | 0.005257623554153523           |
# +-------------------------+------------------------+-----------------------+-----------------------+--------------------------------+
# | Away5LastGames(Good)    | 0.7977977977977977     | 0.0799396681749623    | 0.4425483503981797    | 0.005257623554153523           |
# +-------------------------+------------------------+-----------------------+-----------------------+--------------------------------+
# | Away5LastGames(Neutral) | 0.16116116116116114    | 0.31523378582202116   | 0.42889647326507396   | 0.989484752891693              |
# +-------------------------+------------------------+-----------------------+-----------------------+--------------------------------+

# %%
print(model.get_cpds(ha))
# Out:
# +--------------------------------+-----------------------+---------------+----------------------+---------------------+---------------------+-----------------------+---------------------+----------------------+------------------+-----------------------+---------------------+----------------------+-----------------------+----------------------+---------------------+---------------------+-----------------------+------------------------+---------------------+----------------------+----------------------+----------------+---------------------+----------------------+---------------------+----------------------+-----------------------+---------------------+----------------------+---------------------+----------------------+----------------------+-----------------------+----------------------+----------------------+---------------------+---------------------+---------------------+----------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+-----------------------+---------------------+----------------------+---------------------+---------------------+-----------------------+----------------------+----------------------+----------------------+----------------------+-----------------------+---------------------+----------------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+----------------------+---------------------+---------------------+----------------------+----------------------+---------------------+-------------------------+-----------------------+----------------------+---------------------+----------------------+
# | City                           | City(Amsterdam)       | City(Antwerp) | City(Arnhem)         | City(Aveiro)        | City(Barcelona)     | City(Basel)           | City(Belgrade)      | City(Bern)           | City(Birmingham) | City(Bordeaux)        | City(Braga)         | City(Bruges)         | City(Brussels)        | City(Charleroi)      | City(Coimbra)       | City(Cologne)       | City(Donetsk)         | City(Décines-Charpieu) | City(Düsseldorf)    | City(Eindhoven)      | City(Faro/Loulé)     | City(Florence) | City(Frankfurt)     | City(Gdańsk)         | City(Gelsenkirchen) | City(Geneva)         | City(Gothenburg)      | City(Guimarães)     | City(Hamburg)        | City(Hanover)       | City(Innsbruck)      | City(Kharkiv)        | City(Kiev)            | City(Klagenfurt)     | City(Leeds)          | City(Leiria)        | City(Lens)          | City(Lisbon)        | City(Liverpool)      | City(Liège)          | City(London)        | City(Lviv)           | City(Lyon)          | City(Madrid)        | City(Malmö)          | City(Manchester)      | City(Marseille)     | City(Milan)          | City(Munich)        | City(Nantes)        | City(Naples)          | City(Newcastle)      | City(Nice)           | City(Norrköping)     | City(Nottingham)     | City(Paris)           | City(Porto)         | City(Poznań)         | City(Rome)            | City(Rotterdam)       | City(Saint-Denis)     | City(Saint-Étienne)   | City(Salzburg)       | City(Sheffield)      | City(Solna)          | City(Strasbourg)    | City(Stuttgart)     | City(Toulouse)       | City(Turin)          | City(Vienna)        | City(Villeneuve-d'Ascq) | City(Warsaw)          | City(Wrocław)        | City(Zagreb)        | City(Zürich)         |
# +--------------------------------+-----------------------+---------------+----------------------+---------------------+---------------------+-----------------------+---------------------+----------------------+------------------+-----------------------+---------------------+----------------------+-----------------------+----------------------+---------------------+---------------------+-----------------------+------------------------+---------------------+----------------------+----------------------+----------------+---------------------+----------------------+---------------------+----------------------+-----------------------+---------------------+----------------------+---------------------+----------------------+----------------------+-----------------------+----------------------+----------------------+---------------------+---------------------+---------------------+----------------------+----------------------+---------------------+----------------------+---------------------+---------------------+----------------------+-----------------------+---------------------+----------------------+---------------------+---------------------+-----------------------+----------------------+----------------------+----------------------+----------------------+-----------------------+---------------------+----------------------+-----------------------+-----------------------+-----------------------+-----------------------+----------------------+----------------------+----------------------+---------------------+---------------------+----------------------+----------------------+---------------------+-------------------------+-----------------------+----------------------+---------------------+----------------------+
# | HomeAverageGoals(High)         | 0.5953947368421053    | 0.015625      | 0.3315217391304348   | 0.00806451612903226 | 0.00806451612903226 | 0.49725274725274726   | 0.49193548387096775 | 0.657608695652174    | 0.25             | 0.3980263157894737    | 0.49193548387096775 | 0.4959016393442623   | 0.5683962264150944    | 0.657608695652174    | 0.00806451612903226 | 0.00806451612903226 | 0.7927631578947368    | 0.16758241758241757    | 0.00806451612903226 | 0.3315217391304348   | 0.3315217391304348   | 0.015625       | 0.00806451612903226 | 0.4959016393442623   | 0.00806451612903226 | 0.005434782608695653 | 0.0032894736842105266 | 0.00806451612903226 | 0.9531250000000001   | 0.00806451612903226 | 0.3315217391304348   | 0.3315217391304348   | 0.5953947368421053    | 0.005434782608695653 | 0.005434782608695653 | 0.00806451612903226 | 0.16758241758241757 | 0.2996688741721854  | 0.25                 | 0.004098360655737705 | 0.16758241758241757 | 0.3315217391304348   | 0.49193548387096775 | 0.49193548387096775 |
------------+---------------------+---------------------+----------------------+----------------------+----------------------+---------------------+---------------------+----------------------+----------------------+---------------------+-------------------------+-----------------------+----------------------+---------------------+----------------------+
# | AwayAverageGoals(NoGamePlayed) | 0.2006578947368421    | 0.953125      | 0.3315217391304348   | 0.49193548387096775 | 0.49193548387096775 | 0.16758241758241757 | 0.49193548387096775 | 0.3315217391304348   | 0.25                 | 0.3980263157894737    | 0.00806451612903226 | 0.25                 | 0.28537735849056606   | 0.3315217391304348   | 0.00806451612903226 | 0.49193548387096775 | 0.2006578947368421    | 0.16758241758241757    | 0.49193548387096775 | 0.3315217391304348   | 0.3315217391304348   | 0.953125       | 0.00806451612903226 | 0.25                 | 0.00806451612903226 | 0.3315217391304348   | 0.2006578947368421 | 0.49193548387096775 | 0.015625      | 0.49193548387096775 | 0.3315217391304348   | 0.3315217391304348   | 0.2006578947368421    | 0.3315217391304348   | 0.3315217391304348   | 0.49193548387096775 | 0.3324175824175824  | 0.20033112582781457   | 0.25                 | 0.25        | 0.16758241758241757   | 0.3315217391304348   | 0.00806451612903226 | 0.49193548387096775 | 0.3315217391304348   | 0.2006578947368421    | 0.20033112582781457 | 0.3315217391304348   | 0.00806451612903226 | 0.00806451612903226 | 0.3980263157894737    | 0.3315217391304348   | 0.25       | 0.3315217391304348   | 0.3315217391304348   | 0.2996688741721854  | 0.25                 | 0.3315217391304348   | 0.14386792452830188 | 0.2006578947368421 | 0.28537735849056606 | 0.3324175824175824  | 0.3315217391304348   | 0.3315217391304348   | 0.25                 | 0.49193548387096775 | 0.49193548387096775 | 0.25                 | 0.3315217391304348   | 0.14386792452830188 | 0.16758241758241757     | 0.2006578947368421    | 0.3315217391304348   | 0.49193548387096775 | 0.3315217391304348   |
# +--------------------------------+-----------------------+---------------+----------------------+---------------------+---------------------+---------------------+---------------------+----------------------+----------------------+-----------------------+---------------------+----------------------+-----------------------+----------------------+---------------------+---------------------+-----------------------+------------------------+---------------------+----------------------+----------------------+----------------+---------------------+----------------------+---------------------+----------------------+--------------------+---------------------+---------------+---------------------+----------------------+----------------------+-----------------------+----------------------+----------------------+---------------------+---------------------+-----------------------+----------------------+-------------+-----------------------+----------------------+---------------------+---------------------+----------------------+-----------------------+---------------------+----------------------+---------------------+---------------------+-----------------------+----------------------+------------+----------------------+----------------------+---------------------+----------------------+----------------------+---------------------+--------------------+---------------------+---------------------+----------------------+----------------------+----------------------+---------------------+---------------------+----------------------+----------------------+---------------------+-------------------------+-----------------------+----------------------+---------------------+----------------------+

# %% [markdown]
# We have completely created and trained our Bayesian networks. Let use it to predict results of games in Groups A, B, C and D in 2016.
#
# We write a function to remove the Result column from data and let the model predict, then compare them with real life results.

# %%
def predictAndCompare(start, end, df):
    dfDropResult = df.drop('Result', axis=1)
    predictDf = dfDropResult[start:end][[ha, aa, hl, al, c]]
    print('Prediction:')
    print(model.predict(predictDf))
    print('\n')
    print('Real life results:')
    print(df['Result'][start:end])

# %% [markdown]
# Group A first:

# %%
df[235:241]
# Out:
#     HomeTeamName AwayTeamName Result HomeAverageGoals AwayAverageGoals  \
# 235       France      Romania    Won     NoGamePlayed     NoGamePlayed
# 236      Albania  Switzerland   Lost     NoGamePlayed     NoGamePlayed
# 237      Romania  Switzerland   Draw              Mid              Mid
# 238       France      Albania    Won             High              Low
# 239      Romania      Albania   Lost              Mid              Low
# 240  Switzerland       France   Draw              Mid             High
#
#     Home5LastGames Away5LastGames    Stage               City  Year
# 235        Neutral        Neutral  Group A        Saint-Denis  2016
# 236        Neutral        Neutral  Group A               Lens  2016
# 237            Bad           Good  Group A              Paris  2016
# 238           Good            Bad  Group A          Marseille  2016
# 239            Bad            Bad  Group A   Décines-Charpieu  2016
# 240           Good           Good  Group A  Villeneuve-d'Ascq  2016

# %% [markdown]
# We are not going to predict all 6 games but only the last 4 games, because the first 2 have *NoGamePlayed* value and two teams look technically identical to our model (both NoGamePlayed - Neutral). Therefore the predicted results from first 2 games would not be reliable.

# %%
predictAndCompare(237, 241, df)
# Out:
# Prediction:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 400.60it/s]
#   Result
# 0   Draw
# 1    Won
# 2   Lost
# 3   Draw
#
#
# Real life results:
# 237    Draw
# 238     Won
# 239    Lost
# 240    Draw
# Name: Result, dtype: object

# %% [markdown]
# 4 out of 4 predictions are correct! We didn't expect it to be this accurate, but let's continue to predict other groups to test our model furthermore.

# %% [markdown]
# Group B:

# %%
df[241:247]
# Out:
#     HomeTeamName AwayTeamName Result HomeAverageGoals AwayAverageGoals  \
# 241        Wales     Slovakia    Won     NoGamePlayed     NoGamePlayed
# 242      England       Russia   Draw     NoGamePlayed     NoGamePlayed
# 243       Russia     Slovakia   Lost              Mid              Mid
# 244      England        Wales    Won              Mid             High
# 245       Russia        Wales   Lost              Mid             High
# 246     Slovakia      England   Draw             High             High
#
#     Home5LastGames Away5LastGames    Stage               City  Year
# 241        Neutral        Neutral  Group B           Bordeaux  2016
# 242        Neutral        Neutral  Group B          Marseille  2016
# 243        Neutral            Bad  Group B  Villeneuve-d'Ascq  2016
# 244        Neutral           Good  Group B               Lens  2016
# 245            Bad        Neutral  Group B           Toulouse  2016
# 246        Neutral           Good  Group B      Saint-Étienne  2016

# %% [markdown]
# Now predicting:

# %%
predictAndCompare(243, 247, df)
# Out:
# Prediction:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1335.87it/s]
#   Result
# 0   Lost
# 1   Draw
# 2   Lost
# 3   Draw
#
#
# Real life results:
# 243    Lost
# 244     Won
# 245    Lost
# 246    Draw
# Name: Result, dtype: object

# %% [markdown]
# Only 1 false predictions. Our model is still pretty reliable.

# %% [markdown]
# Group C:

# %%
df[247:253]
# Out:
#          HomeTeamName      AwayTeamName Result HomeAverageGoals  \
# 247            Poland  Northern Ireland    Won     NoGamePlayed
# 248           Germany           Ukraine    Won     NoGamePlayed
# 249           Ukraine  Northern Ireland   Lost              Low
# 250           Germany            Poland   Draw             High
# 251           Ukraine            Poland   Lost              Low
# 252  Northern Ireland           Germany   Lost              Mid
#
#     AwayAverageGoals Home5LastGames Away5LastGames    Stage  \
# 247     NoGamePlayed        Neutral        Neutral  Group C
# 248     NoGamePlayed        Neutral        Neutral  Group C
# 249              Low            Bad            Bad  Group C
# 250              Mid           Good           Good  Group C
# 251              Low            Bad           Good  Group C
# 252              Mid        Neutral           Good  Group C
#
#                   City  Year
# 247               Nice  2016
# 248  Villeneuve-d'Ascq  2016
# 249   Décines-Charpieu  2016
# 250        Saint-Denis  2016
# 251          Marseille  2016
# 252              Paris  2016

# %% [markdown]
# Predicting:

# %%
predictAndCompare(249, 253, df)
# Out:
# Prediction:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1550.29it/s]
#   Result
# 0   Lost
# 1   Lost
# 2   Lost
# 3   Lost
#
#
# Real life results:
# 249    Lost
# 250    Draw
# 251    Lost
# 252    Lost
# Name: Result, dtype: object

# %% [markdown]
# Again, just 1 false prediction. Our model is doing well.

# %% [markdown]
# The last Group:

# %%
df[253:259]
# Out:
#        HomeTeamName    AwayTeamName Result HomeAverageGoals AwayAverageGoals  \
# 253          Turkey         Croatia   Lost     NoGamePlayed     NoGamePlayed
# 254           Spain  Czech Republic    Won     NoGamePlayed     NoGamePlayed
# 255  Czech Republic         Croatia   Draw              Low              Mid
# 256           Spain          Turkey    Won              Mid              Low
# 257  Czech Republic          Turkey   Lost              Mid              Low
# 258         Croatia           Spain    Won             High             High
#
#     Home5LastGames Away5LastGames    Stage           City  Year
# 253        Neutral        Neutral  Group D          Paris  2016
# 254        Neutral        Neutral  Group D       Toulouse  2016
# 255            Bad           Good  Group D  Saint-Étienne  2016
# 256           Good            Bad  Group D           Nice  2016
# 257            Bad            Bad  Group D           Lens  2016
# 258           Good           Good  Group D       Bordeaux  2016

# %% [markdown]
# Predicting:

# %%
predictAndCompare(255, 259, df)
# Out:
# Prediction:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 983.08it/s]
#   Result
# 0   Lost
# 1   Lost
# 2   Lost
# 3    Won
#
#
# Real life results:
# 255    Draw
# 256     Won
# 257    Lost
# 258     Won
# Name: Result, dtype: object

# %% [markdown]
# However, only 2/4 predictions are true this time.

# %% [markdown]
# Because the result of a football match depends on many other factors such as weather, performance of players or even luck. Our data only includes basic information such as total goals and cities. Therefore, it is unlikely that what our model predicts will match perfectly with what happened in real life.

# %% [markdown]
# ### Probability of winning the Euro championship of each country given that this data frame is true

# %% [markdown]
# In this problem, we will create a new model and a new data frame. The data frame consists of all TeamNames and for each team, we will put the value with the highest counts, for every feature. For example, if the Result of a team has 5 "Won", 4 "Lost" and 2 "Draw", we will put "Won" in the Result column.

# %%
def getMost(col, teamName, df):
    counts = {}
    
    for i, row in df.iterrows():
        if row['HomeTeamName'] == teamName:
            value = row['Home' + col]
            # do not count NoGamePlayed
            if value == 'NoGamePlayed':
                continue
            
            if value in counts:
                counts[value] += 1
            else:
                counts[value] = 1
        
        elif row['AwayTeamName'] == teamName:
            value = row['Away' + col]
            # do not count NoGamePlayed
            if value == 'NoGamePlayed':
                continue
                
            if value in counts:
                counts[value] += 1
            else:
                counts[value] = 1
    return max(counts, key=counts.get)

def isChampion(teamName, df):
    for i, row in df.iterrows():
        if row['Stage'] == 'Final':
            if row['HomeTeamName'] == teamName:
                if row['Result'] == 'Won' or row['Result'] == 'Draw':
                    return True
            elif row['AwayTeamName'] == teamName:
                if row['Result'] == 'Lost' or row['Result'] == 'Draw':
                    return True
    return False

# %%
namelist = list(df['HomeTeamName'])
namelist.extend(df['AwayTeamName'])
nameSet = list(set(namelist))

# find 
averageGoals = []
last5Games = []
champion = []
for name in nameSet:
    averageGoals.append(getMost('AverageGoals', name, df))
    last5Games.append(getMost('5LastGames', name, df))
    champion.append(isChampion(name, df))
    
teamStat = pd.DataFrame(getResultAllTeam(df).idxmax(axis=1))
teamStat = teamStat.rename(columns={0: 'Result'})
teamStat['AverageGoals'] = averageGoals
teamStat['5LastGames'] = last5Games
teamStat['IsChampion'] = champion
teamStat
# Out:
#                     Result AverageGoals 5LastGames  IsChampion
# Spain                  Won         High       Good        True
# CIS                   Draw          Mid    Neutral       False
# Poland                Draw          Low    Neutral       False
# Norway                 Won          Mid    Neutral       False
# Albania               Lost          Low        Bad       False
# Iceland                Won          Mid    Neutral       False
# Denmark               Lost          Low    Neutral        True
# Slovenia              Draw         High    Neutral       False
# Ukraine               Lost          Low    Neutral       False
# Turkey                Lost          Low        Bad       False
# FR Yugoslavia         Lost         High    Neutral       False
# Croatia                Won          Mid       Good       False
# Hungary               Lost         High    Neutral       False
# England               Draw         High    Neutral       False
# Switzerland           Lost          Low    Neutral       False
# Sweden                Lost          Mid    Neutral       False
# West Germany           Won         High       Good        True
# Portugal               Won         High       Good        True
# Wales                  Won         High       Good       False
# Yugoslavia            Lost         High    Neutral        True
# Russia                Lost          Mid    Neutral       False
# Slovakia              Lost          Mid    Neutral       False
# Czechoslovakia         Won          Low    Neutral        True
# Germany                Won         High       Good        True
# Czech Republic        Lost          Mid    Neutral       False
# France                 Won         High       Good        True
# Republic of Ireland   Lost          Mid    Neutral       False
# Belgium               Lost          Mid    Neutral       False
# Soviet Union           Won         High       Good        True
# Greece                Lost          Mid    Neutral        True
# Netherlands            Won         High    Neutral        True
# Romania               Lost          Mid    Neutral       False
# Austria               Lost          Low        Bad       False
# Bulgaria              Lost          Mid    Neutral       False
# Latvia                Lost          Mid        Bad       False
# Northern Ireland      Lost          Low    Neutral       False
# Italy                  Won          Mid    Neutral        True
# Scotland              Lost          Low    Neutral       False

# %%
a = 'AverageGoals'
l = '5LastGames'
w = 'IsChampion'

model2 = BayesianModel([(a, w), (l, w), (r, w)])

data2 = teamStat.reset_index(drop=True)
model2.fit(data2, estimator=BayesianEstimator, prior_type="BDeu")

# %% [markdown]
# Here is our prediction.

# %%
predictData2 = data2.drop(w, axis=1)
prediction = model2.predict_probability(predictData2)
prediction['TeamName'] = nameSet
prediction = prediction[['TeamName', 'IsChampion_True']]
prediction
# Out:
#                TeamName  IsChampion_True
# 0                 Spain         0.847938
# 1                   CIS         0.078125
# 2                Poland         0.078125
# 3                Norway         0.343023
# 4               Albania         0.029070
# 5               Iceland         0.343023
# 6               Denmark         0.210714
# 7              Slovenia         0.042373
# 8               Ukraine         0.210714
# 9                Turkey         0.029070
# 10        FR Yugoslavia         0.343023
# 11              Croatia         0.078125
# 12              Hungary         0.343023
# 13              England         0.042373
# 14          Switzerland         0.210714
# 15               Sweden         0.118952
# 16         West Germany         0.847938
# 17             Portugal         0.847938
# 18                Wales         0.847938
# 19           Yugoslavia         0.343023
# 20               Russia         0.118952
# 21             Slovakia         0.118952
# 22       Czechoslovakia         0.921875
# 23              Germany         0.847938
# 24       Czech Republic         0.118952
# 25               France         0.847938
# 26  Republic of Ireland         0.118952
# 27              Belgium         0.118952
# 28         Soviet Union         0.847938
# 29               Greece         0.118952
# 30          Netherlands         0.921875
# 31              Romania         0.118952
# 32              Austria         0.029070
# 33             Bulgaria         0.118952
# 34               Latvia         0.078125
# 35     Northern Ireland         0.210714
# 36                Italy         0.343023
# 37             Scotland         0.210714

# %% [markdown]
# ## Precision score and recall score

# %% [markdown]
# First, we let the model predict the whole data, but droping row that has 'NoGamePlayed', for the same reason as mentioned.

# %%
data_dropNoGamePlay = data[data[ha] != 'NoGamePlayed'].reset_index(drop=True)
actualResults = data_dropNoGamePlay[r]
predictData = data_dropNoGamePlay.drop('Result', axis=1)
predictedResults = (model.predict(predictData))[r]
predictedResults
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 194/194 [00:02<00:00, 96.09it/s]
# 0       Won
# 1       Won
# 2      Lost
# 3       Won
# 4       Won
#        ...
# 203    Lost
# 204     Won
# 205    Draw
# 206    Draw
# 207    Draw
# Name: Result, Length: 208, dtype: object

# %% [markdown]
# Now we write a function to calculate score based on the predicted results and the actual ones

# %%
def precisionRecallScore(result, predictedDf, actualDf):
    truePositive = 0
    falsePositive = 0
    trueNegative = 0
    falseNegative = 0
    for i in range(len(predictedDf.index)):
        predict = predictedDf[i]
        actual = actualDf[i]
        
        if predict == result:
            if actual == result:
                truePositive += 1
            else:
                falsePositive += 1
        else:
            if actual != result:
                trueNegative += 1
            else:
                falseNegative += 1
    precisionScore = truePositive / (truePositive + falsePositive)
    recallScore = truePositive / (truePositive + falseNegative)
    print('Precision score and recall score of "' + result + '":')
    print((precisionScore, recallScore))

# %%
precisionRecallScore('Won', predictedResults, actualResults)
# Out:
# Precision score and recall score of "Won":
# (0.6521739130434783, 0.5357142857142857)

# %%
precisionRecallScore('Lost', predictedResults, actualResults)
# Out:
# Precision score and recall score of "Lost":
# (0.5833333333333334, 0.6447368421052632)

# %%
precisionRecallScore('Draw', predictedResults, actualResults)
# Out:
# Precision score and recall score of "Draw":
# (0.4727272727272727, 0.5416666666666666)

# %% [markdown]
# The scores are pretty decent. Most of them are over 50%. The precision score of "Won" and the recall score of "Lost" even reach 65%.

# %% [markdown]
# ## (d) adjust the structure of the model slightly to see if it improves the scores

# %% [markdown]
# Because the City factor is somewhat variable (meaning there are so many cities), we try removing the City node. Next, we remove 2 edge HomeAverageGoals -> Result and AwayAverageGoals -> Result. Therefore, rather than depending on both average goals and 5 last games , the result now depends only on 5 last games of both teams.

# %%
adjustedModel = BayesianModel([(ha, hl), (aa, al),
                            (hl, r), (al, r)])

adjustedModel.fit(data, estimator=BayesianEstimator, prior_type="BDeu")
predictedResults_adjusted = (adjustedModel.predict(predictData.drop(c, axis=1)))[r]
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 56/56 [00:00<00:00, 764.57it/s]

# %%
precisionRecallScore('Won', predictedResults_adjusted, actualResults)
# Out:
# Precision score and recall score of "Won":
# (0.46616541353383456, 0.7380952380952381)

# %%
precisionRecallScore('Lost', predictedResults_adjusted, actualResults)
# Out:
# Precision score and recall score of "Lost":
# (0.5272727272727272, 0.3815789473684211)

# %%
precisionRecallScore('Draw', predictedResults_adjusted, actualResults)
# Out:
# Precision score and recall score of "Draw":
# (0.45, 0.1875)

# %% [markdown]
# All the scores terribly go down, especially the recall score of "Draw", which drops more than 30%. However, the recall score of "Won" someshow reaches 75%, from which we can infer that 5LastGames has a strong causality with the "Won" result.
#
# **Conclusion:** For this data set, our original model works best compared to others.
